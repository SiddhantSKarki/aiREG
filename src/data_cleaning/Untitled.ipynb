# %%
import pandas as pd

# %%
raw_df = pd.read_csv('../../raw_data/TEMP1')

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CRN                  110 non-null    int64
#  1   SUBJECT              110 non-null    object
#  2   NUMBER               110 non-null    object
#  3   TITLE                110 non-null    object
#  4   SECTION              110 non-null    object
#  5   CAMPUS               110 non-null    object
#  6   CREDITHOURS          110 non-null    int64
#  7   ENROLLMENT/CAPACITY  110 non-null    object
#  8   DELIVERY             110 non-null    object
#  9   MEETING SCHEDULE     110 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 8.7+ KB

# %%
def clean_subject(x):
    texts = x.split('\n')
    return texts[0]
def clean_meet(x):
    # texts = x['MEETING SCHEDULE'].split('\n')
    # x['MEETING DAYS'] = texts[0]
    # x['START TIME'] = texts[1].strip().split('-')[0].strip()
    # x['END TIME'] = texts[1].strip().split('-')[1].strip()
    # x['HALL'] = texts[2].strip().split(' ')[0]
    # x['ROOM'] = texts[2].strip().split(' ')[1]
    # x['START DATE'] = texts[3].strip().split('-')[0].strip()
    # x['END DATE'] = texts[3].strip().split('-')[1].strip()
    # del x['MEETING SCHEDULE']
    return x
def enroll_cap(x):
    text_form = x['ENROLLMENT/CAPACITY'].split('/')
    x['ENROLLMENT'] = int(text_form[0])
    x['CAPACITY'] = int(text_form[1])
    del x['ENROLLMENT/CAPACITY']
    return x

# %%
raw_df['SUBJECT'] = raw_df['SUBJECT'].apply(clean_subject)
clean_df = (raw_df.apply(clean_meet, axis=1)).apply(enroll_cap, axis=1)

# %%
clean_df
# Out:
#        CRN SUBJECT NUMBER                           TITLE SECTION  CAMPUS  \
# 0    14181     CSE    148              Business Computing       A  Oxford
# 1    17114     CSE    148              Business Computing       B  Oxford
# 2    14183     CSE    148              Business Computing       C  Oxford
# 3    14185     CSE    148              Business Computing       D  Oxford
# 4    14186     CSE    148              Business Computing       E  Oxford
# ..     ...     ...    ...                             ...     ...     ...
# 105  19370     CSE    588                Image Processing       A  Oxford
# 106  19668     CSE    602     Emerging Topics in Comp Sci       A  Oxford
# 107  14327     CSE    611  Seminar Attendance Requirement       A  Oxford
# 108  19371     CSE    617               Advanced Networks       A  Oxford
# 109  19583     CSE   620F  Large-Scale Empirical Sftw Eng       A  Oxford
#
#      CREDITHOURS      DELIVERY  \
# 0              3  Face-to-Face
# 1              3  Face-to-Face
# 2              3  Face-to-Face
# 3              3  Face-to-Face
# 4              3  Face-to-Face
# ..           ...           ...
# 105            3  Face-to-Face
# 106            1  Face-to-Face
# 107            0  Face-to-Face
# 108            3  Face-to-Face
# 109            3  Face-to-Face
#
#                                       MEETING SCHEDULE  ENROLLMENT  CAPACITY
# 0    MW\n                                          ...          28        28
# 1    MW\n                                          ...          29        28
# 2    MW\n                                          ...          29        28
# 3    MW\n                                          ...          29        28
# 4    MW\n                                          ...          29        28
# ..                                                 ...         ...       ...
# 105  MW\n                                          ...           9         3
# 106  W\n                                           ...          19        30
# 107                                      01/29 - 05/17           0         0
# 108  TR\n                                          ...          25        30
# 109  TR\n                                          ...          15        30
#
# [110 rows x 11 columns]

# %%
clean_df[clean_df['ENROLLMENT'] < clean_df['CAPACITY']]
# Out:
#        CRN SUBJECT NUMBER                           TITLE SECTION  CAMPUS  \
# 12   15642     CSE    148              Business Computing       N  Oxford
# 18   14217     CSE    148              Business Computing      FF  Oxford
# 22   14219     CSE    148              Business Computing      KK  Oxford
# 29   13384     CSE    174  Fundmntls-Progrming&Prob Solvg       F  Oxford
# 34   19356     CSE    202           Software Requirements       A  Oxford
# 35   17108     CSE    212  Software Engineering for UI/UX       A  Oxford
# 37   19373     CSE    251       Intro to Game Programming       B  Oxford
# 38   12433     CSE    252     Web Application Programming       A  Oxford
# 39   17109     CSE    262   Tech, Ethics & Global Society       A  Oxford
# 40   12856     CSE    262   Tech, Ethics & Global Society       B  Oxford
# 42   12434     CSE    271     Object-Oriented Programming       A  Oxford
# 43   12435     CSE    271     Object-Oriented Programming       B  Oxford
# 46   12857     CSE    271     Object-Oriented Programming       E  Oxford
# 50   12438     CSE    274  Data Abstractions & Structures       A  Oxford
# 51   12858     CSE    274  Data Abstractions & Structures       B  Oxford
# 52   13686     CSE    274  Data Abstractions & Structures       C  Oxford
# 54   12439     CSE    278                       Systems I       A  Oxford
# 57   19358     CSE    301  Software Architecture & Design       A  Oxford
# 58   19359     CSE    301  Software Architecture & Design       B  Oxford
# 59   19360     CSE    302           Software Construction       A  Oxford
# 60   19618     CSE    309   Leading In Project Management       A  Oxford
# 62   17112     CSE    374                    Algorithms I       B  Oxford
# 63   15633     CSE    374                    Algorithms I       C  Oxford
# 64   19363     CSE    374                    Algorithms I       D  Oxford
# 65   14223     CSE    381                       Systems 2       A  Oxford
# 66   14224     CSE    381                       Systems 2       B  Oxford
# 76   19364     CSE    401      Software Quality Assurance       A  Oxford
# 79   19743     CSE    432                Machine Learning       C  Oxford
# 80   12446     CSE    448           Senior Design Project       A  Oxford
# 82   14241     CSE    449           Senior Design Project       B  Oxford
# 83   16317     CSE    449           Senior Design Project       C  Oxford
# 85   14226     CSE    465     Comparative Prog. Languages       A  Oxford
# 87   19745     CSE    465     Comparative Prog. Languages       C  Oxford
# 96   19744     CSE    532                Machine Learning       C  Oxford
# 97   12893     CSE    556       Bioinformatics Principles       A  Oxford
# 98   12860     CSE    565     Comparative Prog. Languages       A  Oxford
# 99   14555     CSE    565     Comparative Prog. Languages       B  Oxford
# 100  19747     CSE    565     Comparative Prog. Languages       C  Oxford
# 106  19668     CSE    602     Emerging Topics in Comp Sci       A  Oxford
# 108  19371     CSE    617               Advanced Networks       A  Oxford
# 109  19583     CSE   620F  Large-Scale Empirical Sftw Eng       A  Oxford
#
#      CREDITHOURS      DELIVERY  \
# 12             3  Face-to-Face
# 18             3  Face-to-Face
# 22             3  Face-to-Face
# 29             3  Face-to-Face
# 34             3  Face-to-Face
# 35             3  Face-to-Face
# 37             3  Face-to-Face
# 38             3  Face-to-Face
# 39             3  Face-to-Face
# 40             3  Face-to-Face
# 42             3  Face-to-Face
# 43             3  Face-to-Face
# 46             3  Face-to-Face
# 50             3  Face-to-Face
# 51             3  Face-to-Face
# 52             3  Face-to-Face
# 54             3  Face-to-Face
# 57             3  Face-to-Face
# 58             3  Face-to-Face
# 59             3  Face-to-Face
# 60             3  Face-to-Face
# 62             3  Face-to-Face
# 63             3  Face-to-Face
# 64             3  Face-to-Face
# 65             3  Face-to-Face
# 66             3  Face-to-Face
# 76             3  Face-to-Face
# 79             3  Face-to-Face
# 80             2  Face-to-Face
# 82             2  Face-to-Face
# 83             2  Face-to-Face
# 85             3  Face-to-Face
# 87             3  Face-to-Face
# 96             3  Face-to-Face
# 97             3  Face-to-Face
# 98             3  Face-to-Face
# 99             3  Face-to-Face
# 100            3  Face-to-Face
# 106            1  Face-to-Face
# 108            3  Face-to-Face
# 109            3  Face-to-Face
#
#                                       MEETING SCHEDULE  ENROLLMENT  CAPACITY
# 12   MW\n                                          ...          26        28
# 18   TR\n                                          ...          27        28
# 22   TR\n                                          ...          27        28
# 29   TR\n                                          ...          23        32
# 34   TR\n                                          ...          20        30
# 35   TR\n                                          ...          27        30
# 37   MW\n                                          ...          23        24
# 38   TR\n                                          ...          14        30
# 39   TR\n                                          ...          21        32
# 40   MW\n                                          ...          17        32
# 42   MW\n                                          ...          17        30
# 43   MW\n                                          ...          20        30
# 46   MW\n                                          ...          35        36
# 50   T\n                                           ...          26        32
# 51   T\n                                           ...          25        32
# 52   T\n                                           ...          17        32
# 54   M\n                                           ...          18        36
# 57   WF\n                                          ...          14        30
# 58   WF\n                                          ...           8        30
# 59   TR\n                                          ...          28        30
# 60   TR\n                                          ...           7        30
# 62   WF\n                                          ...          19        35
# 63   WF\n                                          ...          18        32
# 64   WF\n                                          ...          24        30
# 65   MW\n                                          ...          35        40
# 66   MW\n                                          ...          38        40
# 76   TR\n                                          ...          23        30
# 79   MF\n                                          ...          17        24
# 80   TR\n                                          ...          38        50
# 82   TR\n                                          ...          22        80
# 83   TR\n                                          ...          22        80
# 85   MW\n                                          ...          32        33
# 87   MW\n                                          ...          23        28
# 96   MF\n                                          ...           5         6
# 97   TR\n                                          ...           0         2
# 98   MW\n                                          ...           1         3
# 99   MW\n                                          ...           2         3
# 100  MW\n                                          ...           0         2
# 106  W\n                                           ...          19        30
# 108  TR\n                                          ...          25        30
# 109  TR\n                                          ...          15        30
